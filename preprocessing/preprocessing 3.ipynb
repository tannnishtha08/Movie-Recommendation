# %%
import numpy as np
import pandas as pd
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ## Extracting features of 2018 movies from Wikipedia

# %% [markdown]
# link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"

# %%
# we only have movie data till 2017 for 2018 we can extract data from wikipedia using the below link
#and then merge it with the orignal dataset (preprocessed)

link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
#reading tables from wikipedia 
#2 table
df1 = pd.read_html(link, header=0)[2]
df1.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Lauren Wolkstein (director); Christopher Radcl...
# 2  Simon West (director); Duncan Falconer, Warren...
# 3  Warwick Thornton (director); David Tranter, St...
# 4  Jaume Collet-Serra (director); Byron Willinger...
#
# ...

# %%
#3rd table 
df2 = pd.read_html(link, header=0)[3]
df2.head()
# Out:
#   Opening  Opening.1                       Title  \
# 0   APRIL          6               A Quiet Place
# 1   APRIL          6                    Blockers
# 2   APRIL          6  You Were Never Really Here
# 3   APRIL          6              Chappaquiddick
# 4   APRIL          6                      Pandas
#
#                                   Production company  \
# 0  Paramount Pictures / Platinum Dunes / Sunday N...
# 1  Universal Pictures / Good Universe / Point Gre...
# 2                                     Amazon Studios
# 3                              Entertainment Studios
# 4                       Warner Bros. Pictures / IMAX
#
#                                        Cast and crew  Ref.
# 0  John Krasinski (director/screenplay); Scott Be...  [76]
# 1  Kay Cannon (director); Eben Russell, Jon Hurwi...  [77]
# 2  Lynne Ramsay (director/screenplay); Joaquin Ph...  [78]
# 3  John Curran (director); Taylor Allen, Andrew L...  [79]
# ...

# %%
#4th table 
df3 = pd.read_html(link, header=0)[4]
df3.head()
# Out:
#   Opening  Opening.1                                  Title  \
# 0    JULY          4                        The First Purge
# 1    JULY          6                   Ant-Man and the Wasp
# 2    JULY          6                    Sorry to Bother You
# 3    JULY          6                                Whitney
# 4    JULY         13  Hotel Transylvania 3: Summer Vacation
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / P...
# 1                                     Marvel Studios
# 2                                 Annapurna Pictures
# 3                     Roadside Attractions / Miramax
# 4  Columbia Pictures / Sony Pictures Animation / MRC
#
#                                        Cast and crew   Ref.
# 0  Gerard McMurray (director); James DeMonaco (sc...  [135]
# 1  Peyton Reed (director); Chris McKenna, Erik So...  [136]
# 2  Boots Riley (director/screenplay); Lakeith Sta...  [137]
# ...

# %%
#5th table 
df4 = pd.read_html(link, header=0)[5]
df4.tail()
# Out:
#      Opening  Opening.1                       Title  \
# 61  DECEMBER         25             Holmes & Watson
# 62  DECEMBER         25                        Vice
# 63  DECEMBER         25         On the Basis of Sex
# 64  DECEMBER         25                   Destroyer
# 65  DECEMBER         28  Black Mirror: Bandersnatch
#
#                               Production company  \
# 61  Columbia Pictures / Gary Sanchez Productions
# 62     Annapurna Pictures / Plan B Entertainment
# 63                                Focus Features
# 64                            Annapurna Pictures
# 65                                       Netflix
#
#                                         Cast and crew   Ref.
# 61  Etan Cohen (director/screenplay); Will Ferrell...  [164]
# 62  Adam McKay (director/screenplay); Christian Ba...  [137]
# 63  Mimi Leder (director); Daniel Stiepleman (scre...  [228]
# 64  Karyn Kusama (director); Phil Hay, Matt Manfre...  [260]
# ...

# %%
#merging all the tables (januray to dec)

df = df1.append(df2.append(df3.append(df4, ignore_index=True),ignore_index=True),ignore_index=True)
df.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Lauren Wolkstein (director); Christopher Radcl...
# 2  Simon West (director); Duncan Falconer, Warren...
# 3  Warwick Thornton (director); David Tranter, St...
# 4  Jaume Collet-Serra (director); Byron Willinger...
#
# ...

# %%
df.Opening.value_counts()
# Out:
# MARCH             32
# AUGUST            26
# FEBRUARY          25
# NOVEMBER          25
# OCTOBER           22
# SEPTEMBER         22
# JUNE              22
# JULY              21
# APRIL             21
# MAY               20
# DECEMBER          18
# JANUARY           17
# Bullitt County     1
# Name: Opening, dtype: int64

# %%
df = df[df['Opening'] != 'Bullitt County']
df.Opening.value_counts()
# Out:
# MARCH        32
# AUGUST       26
# FEBRUARY     25
# NOVEMBER     25
# OCTOBER      22
# SEPTEMBER    22
# JUNE         22
# JULY         21
# APRIL        21
# MAY          20
# DECEMBER     18
# JANUARY      17
# Name: Opening, dtype: int64

# %% [markdown]
# - we don't have genres of the listed movies of 2018. To achieve that we will use tmdb API and extract the genres of these set of movies

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'a6a1a53e9ce9c20e950add9d7b94b480'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genre = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " "
        for i in range(0, len(data_json['genres'])):
            genre.append(data_json['genres'][i]['name'])
        return genre_str.join(genre)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df.head()
# Out:
#    Opening  Opening.1                    Title  \
# 0  JANUARY          5  Insidious: The Last Key
# 1  JANUARY          5         The Strange Ones
# 2  JANUARY          5                 Stratton
# 3  JANUARY         10            Sweet Country
# 4  JANUARY         12             The Commuter
#
#                                   Production company  \
# 0  Universal Pictures / Blumhouse Productions / S...
# 1                             Vertical Entertainment
# 2                                  Momentum Pictures
# 3                               Samuel Goldwyn Films
# 4      Lionsgate / StudioCanal / The Picture Company
#
#                                        Cast and crew  \
# 0  Adam Robitel (director); Leigh Whannell (scree...
# 1  Lauren Wolkstein (director); Christopher Radcl...
# 2  Simon West (director); Duncan Falconer, Warren...
# 3  Warwick Thornton (director); David Tranter, St...
# 4  Jaume Collet-Serra (director); Byron Willinger...
#
# ...

# %%
df_2018  = df[['Title','Cast and crew', 'genres']]
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres
# 0  Horror Mystery Thriller
# 1           Thriller Drama
# 2          Action Thriller
# 3    Drama History Western
# 4          Action Thriller

# %%
df_2018['Cast and crew'][0]
# Out:
# 'Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Kirk Acevedo, Bruce Davison'

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].apply(lambda x: get_director(x))
df_2018.head()
# Out:
# <ipython-input-27-876794f71e0a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].apply(lambda x: get_director(x))
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres       director_name
# ...

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])
df_2018['actor_1_name'] = df_2018['Cast and crew'].apply(lambda x: get_actor1(x))
df_2018.head()
# Out:
# <ipython-input-28-6318e7312589>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].apply(lambda x: get_actor1(x))
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres       director_name    actor_1_name
# ...

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
df_2018.head()
# Out:
# <ipython-input-30-ee1e436e5fbd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres       director_name    actor_1_name  \
# ...

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
df_2018.head()
# Out:
# <ipython-input-31-f08d6c1827cd>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres       director_name    actor_1_name  \
# ...

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18['actor_1_name'] = new_df18['actor_1_name'].replace(np.nan, 'unknown')

new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')
new_df18['movie_title'] = new_df18['movie_title'].str.lower()
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18.head()
# Out:
#         director_name    actor_1_name            actor_2_name    actor_3_name  \
# 0        Adam Robitel       Lin Shaye           Angus Sampson  Leigh Whannell
# 1    Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2          Simon West  Dominic Cooper          Austin Stowell      Gemma Chan
# 3    Warwick Thornton     Bryan Brown               Sam Neill         unknown
# 4  Jaume Collet-Serra     Liam Neeson            Vera Farmiga  Patrick Wilson
#
#                     genres              movie_title  \
# 0  Horror Mystery Thriller  insidious: the last key
# 1           Thriller Drama         the strange ones
# 2          Action Thriller                 stratton
# 3    Drama History Western            sweet country
# 4          Action Thriller             the commuter
#
#                                                 comb
# 0  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1  Alex Pettyfer James Freedson-Jackson Emily Alt...
# ...

# %% [markdown]
# ## Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df_2019 = df[['Title','Cast and crew','genres']]
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))
df_2019 = df_2019.rename(columns={'Title':'movie_title'})
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')
new_df19['movie_title'] = new_df19['movie_title'].str.lower()
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']
# Out:
# <ipython-input-36-051cb2a18437>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# <ipython-input-36-051cb2a18437>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# <ipython-input-36-051cb2a18437>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
new_df19.head()
# Out:
#           director_name         actor_1_name        actor_2_name  \
# 0          Adam Robitel       Taylor Russell        Logan Miller
# 1           Jen McGowan    Hermione Corfield         Jay Paulson
# 2     Wilson Coneybeare    Donald Sutherland  Vincent Kartheiser
# 3  Charles Martin Smith  Bryce Dallas Howard  Edward James Olmos
# 4           Neil Burger       Bryan Cranston          Kevin Hart
#
#        actor_3_name                   genres       movie_title  \
# 0  Deborah Ann Woll  Horror Thriller Mystery       escape room
# 1      Sean O'Bryan           Thriller Drama        rust creek
# 2     Oliver Dennis                 Thriller  american hangman
# 3   Alexandra Shipp   Drama Adventure Family  a dog's way home
# 4     Nicole Kidman             Comedy Drama        the upside
#
#                                                 comb
# 0  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# ...

# %%
my_df = new_df18.append(new_df19, ignore_index=True)
my_df.head()
# Out:
#         director_name    actor_1_name            actor_2_name    actor_3_name  \
# 0        Adam Robitel       Lin Shaye           Angus Sampson  Leigh Whannell
# 1    Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2          Simon West  Dominic Cooper          Austin Stowell      Gemma Chan
# 3    Warwick Thornton     Bryan Brown               Sam Neill         unknown
# 4  Jaume Collet-Serra     Liam Neeson            Vera Farmiga  Patrick Wilson
#
#                     genres              movie_title  \
# 0  Horror Mystery Thriller  insidious: the last key
# 1           Thriller Drama         the strange ones
# 2          Action Thriller                 stratton
# 3    Drama History Western            sweet country
# 4          Action Thriller             the commuter
#
#                                                 comb
# 0  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1  Alex Pettyfer James Freedson-Jackson Emily Alt...
# ...

# %%
old_df = pd.read_csv('new_data.csv')
old_df.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# ...

# %%
final_df = old_df.append(my_df, ignore_index=True)
final_df.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# ...

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           2
# movie_title      0
# comb             2
# dtype: int64

# %%
final_df  = final_df.dropna(how='any')
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('final_data.csv', index=False)
